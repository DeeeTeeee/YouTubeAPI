# %% [markdown]
# # YouTube Channels Web Sracping with EDA Project Part 2
#
# ## By David Anifowoshe

# %% [markdown]
# Generating API Key

# %%
#import libraries:
from googleapiclient.discovery import build
import numpy as np
import pandas as pd
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Extracting Data from youtube top channels:

# %%
api_key = 'AIzaSyATWUhXp0dRhNlhMBjRS4aSp_ejZsFkZIw'
channel_ids = [
    'UCq-Fj5jknLsUf-MWSy4_brA',  # T-Series
    'UCbCmjCuTUZos6Inko4u57UQ',  # Cocomelon  UCbCmjCuTUZos6Inko4u57UQ
    'UCpEhnqL0y41EpW2TvWAHD7Q',  # SET India UCpEhnqL0y41EpW2TvWAHD7Q
    'UCX6OQ3DkcsbYNE6H8uQQuVA',  # MrBeast UCX6OQ3DkcsbYNE6H8uQQuVA
    'UC-lHJZR3Gqxm24_Vd_AJ5Yw',  # PewDiePie UC-lHJZR3Gqxm24_Vd_AJ5Yw
    'UCk8GzjMOrta8yxDcKfylJYw',  # Kids Diana Show UCk8GzjMOrta8yxDcKfylJYw
    'UCJplp5SjeGSdVdwsfb9Q7lQ',  # Like Nastya UCJplp5SjeGSdVdwsfb9Q7lQ
    'UCJ5v_MCY6GNUBTO8-D3XoAg',  # WWE UCJ5v_MCY6GNUBTO8-D3XoAg
    'UCvlE5gTbOvjiolFlEm-c_Ow',  # Vlad and Niki UCvlE5gTbOvjiolFlEm-c_Ow
    'UCFFbwnve3yF62-tVXkTyHqg',  # Zee Music Company UCFFbwnve3yF62-tVXkTyHqg
    'UCOmHUn--16B90oW2L6FRR3A',  # Blackpink UCOmHUn--16B90oW2L6FRR3A
    'UCyoXW-Dse7fURq30EWl_CUA',  # Goldmines UCyoXW-Dse7fURq30EWl_CUA
    'UC295-Dw_tDNtZXFeAPAW6Aw',  # 5-Minute Crafts UC295-Dw_tDNtZXFeAPAW6Aw
    'UC6-F5tO8uklgE9Zy8IvbdFw',  # Sony SAB UC6-F5tO8uklgE9Zy8IvbdFw
    'UCLkAepWjdylmXSltofFvsYQ',  # BangtanTV UCLkAepWjdylmXSltofFvsYQ
    'UCIwFjwMjI0y7PDBVEO9-bkQ',  # Justin Bieber UCIwFjwMjI0y7PDBVEO9-bkQ
    'UC3IZKseVpdzPSBaWxBxundA',  # Hybe Labels UC3IZKseVpdzPSBaWxBxundA
    'UCffDXn7ycAzwL2LDlbyWOTw',  # Canal KondZilla UCffDXn7ycAzwL2LDlbyWOTw
    'UCEc2Kgm_u-3c8iR49sJ82_g',  # Zee TV
    'UCcdwLMPsaU2ezNSJU1nFoBQ',  # Pinkfong UCcdwLMPsaU2ezNSJU1nFoBQ
    'UCF1JIbMUs6uqoZEY1Haw0GQ',  # Shemaroo Entertainment UCF1JIbMUs6uqoZEY1Haw0GQ
    'UCBnZ16ahKA2DZ_T5W0FPUXg',  # ChuChu TV UCBnZ16ahKA2DZ_T5W0FPUXg
    'UC55IWqFLDH1Xp7iu1_xknRA',  # Colors TV UC55IWqFLDH1Xp7iu1_xknRA
    'UCRijo3ddMTht_IHyNSNXpNQ',  # Dude Perfect UCRijo3ddMTht_IHyNSNXpNQ
tube = build('youtube', 'v3', developerKey=api_key)

# %% [markdown]
# we now need to get the channels details:

# %%
'''
function to get channels stats
'''
def get_channel_stats(youtube, taaooma):
  request = youtube.channels().list(
              part='snippet, contentDetails, statistics',
              id=taaooma)
  response = request.execute()
  return response

# %%
def get_channel_stats(youtube, channel_ids):
  all_data= []
  request = youtube.channels().list(
              part='snippet, contentDetails, statistics',
              id=','.join(channel_ids))
  response = request.execute()

  '''
  getting the items in multiple channels, by looping through each of the items:

  '''
  for i in range(len(response['items'])):
      data = dict(channel_name = response['items'][i]['snippet']['title'],
              published= response['items'][i]['snippet']['publishedAt'],
              Subscribers = response['items'][i]['statistics']['subscriberCount'],
              Views = response['items'][i]['statistics']['viewCount'],
              Video_Count = response['items'][i]['statistics']['videoCount'])
      all_data.append(data)
  return all_data

# %%
get_channel_stats(youtube, channel_ids)
# Out:
# [{'channel_name': 'Like Nastya',
#   'published': '2016-12-06T12:15:52Z',
#   'Subscribers': '108000000',
#   'Views': '93299303187',
#   'Video_Count': '838'},
#  {'channel_name': 'Cocomelon - Nursery Rhymes',
#   'published': '2006-09-01T22:18:49Z',
#   'Subscribers': '166000000',
#   'Views': '168578827999',
#   'Video_Count': '1018'},
#  {'channel_name': 'WaveMusic',
#   'published': '2011-12-20T23:39:50Z',
#   'Subscribers': '4640000',
#   'Views': '2284259953',
#   'Video_Count': '1891'},
#  {'channel_name': 'Canal KondZilla',
#   'published': '2012-03-21T23:40:47Z',
#   'Subscribers': '66700000',
#   'Views': '37607324755',
#   'Video_Count': '2656'},
#  {'channel_name': 'T-Series',
#   'published': '2006-03-13T14:27:05Z',
#   'Subscribers': '251000000',
#   'Views': '235531677779',
#   'Video_Count': '19651'},
#  {'channel_name': 'Billie Eilish',
#   'published': '2013-02-06T23:21:04Z',
#   'Subscribers': '48700000',
#   'Views': '14184863896',
#   'Video_Count': '77'},
#  {'channel_name': 'ChuChu TV Nursery Rhymes & Kids Songs',
#   'published': '2013-02-09T07:51:48Z',
#   'Subscribers': '68100000',
#   'Views': '47611706137',
#   'Video_Count': '698'},
#  {'channel_name': 'Bad Bunny',
#   'published': '2014-06-09T02:50:42Z',
#   'Subscribers': '46900000',
#   'Views': '31945455471',
#   'Video_Count': '152'},
#  {'channel_name': 'PewDiePie',
#   'published': '2010-04-29T10:54:00Z',
#   'Subscribers': '111000000',
#   'Views': '29145039320',
#   'Video_Count': '4731'},
#  {'channel_name': 'Goldmines',
#   'published': '2012-01-21T08:42:21Z',
#   'Subscribers': '91000000',
#   'Views': '26003879843',
#   'Video_Count': '6956'},
#  {'channel_name': 'Sony Music India',
#   'published': '2009-09-02T23:16:22Z',
#   'Subscribers': '58200000',
#   'Views': '29701906138',
#   'Video_Count': '4100'},
#  {'channel_name': 'Aaj Tak',
#   'published': '2009-08-27T11:54:24Z',
#   'Subscribers': '59400000',
#   'Views': '26761701081',
#   'Video_Count': '307667'},
#  {'channel_name': 'Badabun',
#   'published': '2014-10-14T00:15:54Z',
#   'Subscribers': '47000000',
#   'Views': '19534332764',
#   'Video_Count': '19250'},
#  {'channel_name': 'SET India',
#   'published': '2006-09-20T22:24:59Z',
#   'Subscribers': '164000000',
#   'Views': '152521739081',
#   'Video_Count': '119657'},
#  {'channel_name': 'whinderssonnunes',
#   'published': '2013-01-21T13:06:10Z',
#   'Subscribers': '44300000',
#   'Views': '4345262097',
#   'Video_Count': '630'},
#  {'channel_name': 'Sony SAB',
#   'published': '2007-08-04T16:05:01Z',
#   'Subscribers': '86200000',
#   'Views': '105458984984',
#   'Video_Count': '74547'},
#  {'channel_name': 'Zee Music Company',
#   'published': '2014-03-12T11:59:25Z',
#   'Subscribers': '101000000',
#   'Views': '60868167950',
#   'Video_Count': '9197'},
#  {'channel_name': 'LooLoo Kids - Topic',
#   'published': '2017-09-20T10:10:18Z',
#   'Subscribers': '254000',
#   'Views': '9206354',
#   'Video_Count': '522'},
#  {'channel_name': 'BRIGHT SIDE',
#   'published': '2017-03-15T11:17:50Z',
#   'Subscribers': '44500000',
#   'Views': '10822852560',
#   'Video_Count': '6662'},
#  {'channel_name': 'Tips Official',
#   'published': '2007-05-22T10:13:28Z',
#   'Subscribers': '61600000',
#   'Views': '35018484553',
#   'Video_Count': '5028'},
#  {'channel_name': 'Colors TV',
#   'published': '2008-06-13T11:09:32Z',
#   'Subscribers': '67400000',
#   'Views': '64759199822',
#   'Video_Count': '119824'},
#  {'channel_name': 'Dude Perfect',
#   'published': '2009-03-17T05:44:36Z',
#   'Subscribers': '59800000',
#   'Views': '16648328872',
#   'Video_Count': '399'},
#  {'channel_name': 'HYBE LABELS',
#   'published': '2008-06-04T08:23:22Z',
#   'Subscribers': '73000000',
#   'Views': '30475727411',
#   'Video_Count': '1478'},
#  {'channel_name': 'BillionSurpriseToys  - Nursery Rhymes & Cartoons',
#   'published': '2013-10-25T23:18:43Z',
#   'Subscribers': '53700000',
#   'Views': '10774127607',
#   'Video_Count': '899'},
#  {'channel_name': 'Infobells - Hindi',
#   'published': '2014-06-06T15:24:36Z',
#   'Subscribers': '56500000',
#   'Views': '32514100250',
#   'Video_Count': '602'},
#  {'channel_name': 'Justin Bieber',
#   'published': '2007-01-15T21:17:27Z',
#   'Subscribers': '72000000',
#   'Views': '31034548393',
#   'Video_Count': '249'},
#  {'channel_name': 'Você Sabia?',
#   'published': '2013-09-01T23:31:56Z',
#   'Subscribers': '45000000',
#   'Views': '7937100738',
#   'Video_Count': '1609'},
#  {'channel_name': 'El Reino Infantil',
#   'published': '2011-06-02T16:20:07Z',
#   'Subscribers': '60300000',
#   'Views': '59545255685',
#   'Video_Count': '1560'},
#  {'channel_name': 'Vlad and Niki',
#   'published': '2018-04-23T13:58:18Z',
#   'Subscribers': '102000000',
#   'Views': '79947244012',
#   'Video_Count': '602'},
#  {'channel_name': 'YRF',
#   'published': '2006-06-07T23:07:50Z',
#   'Subscribers': '56300000',
#   'Views': '37016368314',
#   'Video_Count': '3815'},
#  {'channel_name': '✿ Kids Diana Show',
#   'published': '2015-05-12T08:26:57Z',
#   'Subscribers': '114000000',
#   'Views': '95642677267',
#   'Video_Count': '1128'},
#  {'channel_name': 'MrBeast',
#   'published': '2012-02-20T00:43:50Z',
#   'Subscribers': '201000000',
#   'Views': '34867577871',
#   'Video_Count': '759'},
#  {'channel_name': 'BLACKPINK',
#   'published': '2016-06-29T03:15:23Z',
#   'Subscribers': '91800000',
#   'Views': '33567618140',
#   'Video_Count': '584'},
#  {'channel_name': 'T-Series Bhakti Sagar',
#   'published': '2011-02-13T18:21:00Z',
#   'Subscribers': '63500000',
#   'Views': '31024850952',
#   'Video_Count': '26553'},
#  {'channel_name': 'EminemMusic',
#   'published': '2007-02-09T00:01:36Z',
#   'Subscribers': '57600000',
#   'Views': '27699247917',
#   'Video_Count': '156'},
#  {'channel_name': 'Marshmello',
#   'published': '2015-04-06T21:21:50Z',
#   'Subscribers': '56600000',
#   'Views': '14716827669',
#   'Video_Count': '448'},
#  {'channel_name': 'Fernanfloo',
#   'published': '2011-05-02T05:32:42Z',
#   'Subscribers': '46500000',
#   'Views': '10408806437',
#   'Video_Count': '544'},
#  {'channel_name': 'SonyMusicIndiaVEVO',
#   'published': '2009-09-02T23:38:43Z',
#   'Subscribers': '47800000',
#   'Views': '28402256253',
#   'Video_Count': '3529'},
#  {'channel_name': 'Shemaroo',
#   'published': '2007-09-01T11:44:51Z',
#   'Subscribers': '49300000',
#   'Views': '23331925542',
#   'Video_Count': '11829'},
#  {'channel_name': 'Taylor Swift',
#   'published': '2006-09-20T21:05:35Z',
#   'Subscribers': '54500000',
#   'Views': '31372088899',
#   'Video_Count': '220'},
#  {'channel_name': 'Ed Sheeran',
#   'published': '2006-08-08T13:59:50Z',
#   'Subscribers': '53700000',
#   'Views': '30847079439',
#   'Video_Count': '447'},
#  {'channel_name': 'Felipe Neto',
#   'published': '2006-05-16T06:56:06Z',
#   'Subscribers': '45600000',
#   'Views': '16971732770',
#   'Video_Count': '4474'},
#  {'channel_name': 'Movieclips',
#   'published': '2006-04-28T00:02:37Z',
#   'Subscribers': '59900000',
#   'Views': '60044302148',
#   'Video_Count': '39612'},
#  {'channel_name': "Pinkfong Baby Shark - Kids' Songs & Stories",
#   'published': '2011-12-14T04:54:24Z',
#   'Subscribers': '70300000',
#   'Views': '40278131783',
#   'Video_Count': '3000'},
#  {'channel_name': 'WWE',
#   'published': '2007-05-11T01:20:02Z',
#   'Subscribers': '97600000',
#   'Views': '79429599682',
#   'Video_Count': '71869'},
#  {'channel_name': '5-Minute Crafts',
#   'published': '2016-11-15T09:25:37Z',
#   'Subscribers': '80300000',
#   'Views': '26630666470',
#   'Video_Count': '6610'},
#  {'channel_name': 'Ariana Grande',
#   'published': '2007-01-22T01:53:12Z',
#   'Subscribers': '53000000',
#   'Views': '24426436772',
#   'Video_Count': '154'},
#  {'channel_name': 'BANGTANTV',
#   'published': '2012-12-17T03:20:38Z',
#   'Subscribers': '76600000',
#   'Views': '21574999725',
#   'Video_Count': '2352'},
#  {'channel_name': 'JuegaGerman',
#   'published': '2013-05-19T00:09:13Z',
#   'Subscribers': '48700000',
#   'Views': '14864038836',
#   'Video_Count': '2077'}]
