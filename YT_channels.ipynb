# %% [markdown]
# # YouTube Channels Web Sracping with EDA Project Part 2
#
# ## By David Anifowoshe

# %% [markdown]
# Generating API Key

# %%
#import libraries:
from googleapiclient.discovery import build
import numpy as np
import pandas as pd
import plotly.express as px
import seaborn as sns
import warnings
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Extracting Data from youtube top channels:

# %%
api_key = 'AIzaSyATWUhXp0dRhNlhMBjRS4aSp_ejZsFkZIw'
channel_ids = [
    'UCq-Fj5jknLsUf-MWSy4_brA',  # T-Series
    'UCbCmjCuTUZos6Inko4u57UQ',  # Cocomelon  UCbCmjCuTUZos6Inko4u57UQ
    'UCpEhnqL0y41EpW2TvWAHD7Q',  # SET India UCpEhnqL0y41EpW2TvWAHD7Q
    'UCX6OQ3DkcsbYNE6H8uQQuVA',  # MrBeast UCX6OQ3DkcsbYNE6H8uQQuVA
    'UC-lHJZR3Gqxm24_Vd_AJ5Yw',  # PewDiePie UC-lHJZR3Gqxm24_Vd_AJ5Yw
    'UCk8GzjMOrta8yxDcKfylJYw',  # Kids Diana Show UCk8GzjMOrta8yxDcKfylJYw
    'UCJplp5SjeGSdVdwsfb9Q7lQ',  # Like Nastya UCJplp5SjeGSdVdwsfb9Q7lQ
    'UCJ5v_MCY6GNUBTO8-D3XoAg',  # WWE UCJ5v_MCY6GNUBTO8-D3XoAg
    'UCvlE5gTbOvjiolFlEm-c_Ow',  # Vlad and Niki UCvlE5gTbOvjiolFlEm-c_Ow
    'UCFFbwnve3yF62-tVXkTyHqg',  # Zee Music Company UCFFbwnve3yF62-tVXkTyHqg
    'UCOmHUn--16B90oW2L6FRR3A',  # Blackpink UCOmHUn--16B90oW2L6FRR3A
    'UCyoXW-Dse7fURq30EWl_CUA',  # Goldmines UCyoXW-Dse7fURq30EWl_CUA
    'UC295-Dw_tDNtZXFeAPAW6Aw',  # 5-Minute Crafts UC295-Dw_tDNtZXFeAPAW6Aw
    'UC6-F5tO8uklgE9Zy8IvbdFw',  # Sony SAB UC6-F5tO8uklgE9Zy8IvbdFw
    'UCLkAepWjdylmXSltofFvsYQ',  # BangtanTV UCLkAepWjdylmXSltofFvsYQ
    'UCIwFjwMjI0y7PDBVEO9-bkQ',  # Justin Bieber UCIwFjwMjI0y7PDBVEO9-bkQ
    'UC3IZKseVpdzPSBaWxBxundA',  # Hybe Labels UC3IZKseVpdzPSBaWxBxundA
    'UCffDXn7ycAzwL2LDlbyWOTw',  # Canal KondZilla UCffDXn7ycAzwL2LDlbyWOTw
    'UCEc2Kgm_u-3c8iR49sJ82_g',  # Zee TV
    'UCcdwLMPsaU2ezNSJU1nFoBQ',  # Pinkfong UCcdwLMPsaU2ezNSJU1nFoBQ
    'UCF1JIbMUs6uqoZEY1Haw0GQ',  # Shemaroo Entertainment UCF1JIbMUs6uqoZEY1Haw0GQ
    'UCBnZ16ahKA2DZ_T5W0FPUXg',  # ChuChu TV UCBnZ16ahKA2DZ_T5W0FPUXg
    'UC55IWqFLDH1Xp7iu1_xknRA',  # Colors TV UC55IWqFLDH1Xp7iu1_xknRA
    'UCRijo3ddMTht_IHyNSNXpNQ',  # Dude Perfect UCRijo3ddMTht_IHyNSNXpNQ
    'UC3gNmTGu-TTbFPpfSs5kNkg',  # Movieclips UC3gNmTGu-TTbFPpfSs5kNkg
    'UCaayLD9i5x4MmIoVZxXSv_g',  # T-Series Bhakti Sagar UCaayLD9i5x4MmIoVZxXSv_g
    'UCJrDMFOdv1I2k8n9oK_V21w',  # Tips Industries UCJrDMFOdv1I2k8n9oK_V21w
    'UCEdvpU2pFRCVqU6yIPyTpMQ',  # Marshmello UCEdvpU2pFRCVqU6yIPyTpMQ
    'UCbuK8xxu2P_sqoMnDsoBrrg',  # Wave Music UCbuK8xxu2P_sqoMnDsoBrrg
    'UC56gTxNs4f9xZ7Pa2i5xNzg',  # Sony Music India UC56gTxNs4f9xZ7Pa2i5xNzg
    'UCt4t-jeY85JegMlZ-E5UWtA',  # Aaj Tak UCt4t-jeY85JegMlZ-E5UWtA
    'UCfM3zsQsOnfWNUppiycmBuw',  # Eminem UC2pmfLm7iq6Ov1UwYrWYkZA
    'UCK1i2UviaXLUNrZlAFpw_jA',  # El Reino Infantil UCK1i2UviaXLUNrZlAFpw_jA
    'UC0C-w0YjGpqDXGB8IHb662A',  # Ed Sheeran UC0C-w0YjGpqDXGB8IHb662A
    'UC9CoOnJkIBMdeijd9qYoT_g',  # Ariana Grande UC9CoOnJkIBMdeijd9qYoT_g
    'UCDfGfxMpfVquXZ4qyjupX7w',  # LooLoo Kids UCDfGfxMpfVquXZ4qyjupX7w
    'UCbTLwN10NoCU4WDzLf1JMOA',  # Yash Raj Films UCbTLwN10NoCU4WDzLf1JMOA
    'UCqECaJ8Gagnn7YCbPEzWH6g',  # Taylor Swift UCqECaJ8Gagnn7YCbPEzWH6g
    'UCRx3mKNUdl8QE06nEug7p6Q',  # BillionSurpriseToys UCRx3mKNUdl8QE06nEug7p6Q
    'UC1ciY6kR3yj3kaKZ6R7ewAg',  # Infobells UC1ciY6kR3yj3kaKZ6R7ewAg
    'UCiGm_E4ZwYSHV3bcW1pnSeQ',  # Billie Eilish UCiGm_E4ZwYSHV3bcW1pnSeQ
    'UCYiGq8XF7YQD00x7wAd62Zg',  # JuegaGerman UCYiGq8XF7YQD00x7wAd62Zg
    'UCYWOjHweP2V-8kGKmmAmQJQ',  # Badabun UCYWOjHweP2V-8kGKmmAmQJQ
    'UCV4xOVpbcV8SdueDCOxLXtQ',  # Fernanfloo UCV4xOVpbcV8SdueDCOxLXtQ
    'UCmBA_wu8xGg1OfOkfW13Q0Q',  # Bad Bunny UCmBA_wu8xGg1OfOkfW13Q0Q
    'UCV306eHqgo0LvBf3Mh36AHg',  # Felipe Neto UCV306eHqgo0LvBf3Mh36AHg
    'UC3MLnJtqc_phABBriLRhtgQ',  # SonyMusicIndiaVEVO UC3MLnJtqc_phABBriLRhtgQ
    'UC4rlAVgAK0SGk-yTfe48Qpw',  # Bright Side UC4rlAVgAK0SGk-yTfe48Qpw
    'UCj0O6W8yDuLg3iraAXKgCrQ',  # Você Sabia? UCj0O6W8yDuLg3iraAXKgCrQ
    'UC3KQ5GWANYF8lChqjZpXsQw'  # Whindersson Nunes UC3KQ5GWANYF8lChqjZpXsQw
]



youtube = build('youtube', 'v3', developerKey=api_key)

# %% [markdown]
# we now need to get the channels details:

# %%
'''
function to get channels stats
'''
def get_channel_stats(youtube, taaooma):
  request = youtube.channels().list(
              part='snippet, contentDetails, statistics',
              id=taaooma)
  response = request.execute()
  return response

# %%
def get_channel_stats(youtube, channel_ids):
  all_data= []
  request = youtube.channels().list(
              part='snippet, contentDetails, statistics',
              id=','.join(channel_ids))
  response = request.execute()

  '''
  getting the items in multiple channels, by looping through each of the items:

  '''
  for i in range(len(response['items'])):
      data = dict(channel_name = response['items'][i]['snippet']['title'],
              published= response['items'][i]['snippet']['publishedAt'],
              Subscribers = response['items'][i]['statistics']['subscriberCount'],
              Views = response['items'][i]['statistics']['viewCount'],
              Video_Count = response['items'][i]['statistics']['videoCount'])
      all_data.append(data)
  return all_data

# %%
top_yt = get_channel_stats(youtube, channel_ids)

# %% [markdown]
# let us now make it a dataframe:

# %%
top_yt50 = pd.DataFrame(top_yt)

# %%
top_yt50
# Out:
#                                         channel_name             published  \
# 0                                 SonyMusicIndiaVEVO  2009-09-02T23:38:43Z
# 1                                LooLoo Kids - Topic  2017-09-20T10:10:18Z
# 2                                          Colors TV  2008-06-13T11:09:32Z
# 3                                        Felipe Neto  2006-05-16T06:56:06Z
# 4                         Cocomelon - Nursery Rhymes  2006-09-01T22:18:49Z
# 5                                           T-Series  2006-03-13T14:27:05Z
# 6                                          PewDiePie  2010-04-29T10:54:00Z
# 7                                  ✿ Kids Diana Show  2015-05-12T08:26:57Z
# 8                                          SET India  2006-09-20T22:24:59Z
# 9                                         Movieclips  2006-04-28T00:02:37Z
# 10                                      Taylor Swift  2006-09-20T21:05:35Z
# ...

# %% [markdown]
# # EDA

# %%
top_yt50.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   channel_name  49 non-null     object
#  1   published     49 non-null     object
#  2   Subscribers   49 non-null     object
#  3   Views         49 non-null     object
#  4   Video_Count   49 non-null     object
# dtypes: object(5)
# memory usage: 2.0+ KB

# %%
# Convert columns to numeric
top_yt50['Subscribers'] = top_yt50['Subscribers'].str.replace(',', '').astype(int)
top_yt50['Views'] = top_yt50['Views'].str.replace(',', '').astype(int)
top_yt50['Video_Count'] = top_yt50['Video_Count'].astype(int)

# %% [markdown]
# Who has the highest number of Subsribers?

# %%
# ax = sns.barplot(x='channel_name', y='Subscribers', data =top_yt50)


# Sort the DataFrame by Subscribers in descending order
top_yt50_sorted = top_yt50.sort_values(by="Subscribers", ascending=False)

# Create the bar chart
fig = px.bar(top_yt50_sorted.head(10), x="Subscribers", y="channel_name",
             title="Top 10 YouTube Channels with the Highest Subscribers",
             labels={"Subscribers": "Subscribers Count", "channel_name": "Channel Name"})

# Customize the appearance of the chart
fig.update_traces(marker_color='rgb(86, 171, 47)', marker_line_color='rgb(86, 171, 47)',
                  marker_line_width=1.5, opacity=0.6)

fig.update_layout(plot_bgcolor='black', paper_bgcolor='black',
                  xaxis_title="Subscribers", yaxis_title="Channel Name")

# Show the chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# we can see that T-Series is having well over 250m subscribers, followed by MrBeast with over 200m and the third is Cocomelon with over 160m.
#
# Ok, lets check for Numbers of veiws:

# %%
import plotly.express as px

# Sort the DataFrame by Views in descending order
top_yt50_sorted = top_yt50.sort_values(by="Views", ascending=False)

# Create the bar chart with a blue gradient color scale
fig = px.bar(top_yt50_sorted.head(10), x="Views", y="channel_name",
             title="Top 10 YouTube Channels with the Highest Views",
             labels={"Views": "Views Count", "channel_name": "Channel Name"},
             color="Views", color_continuous_scale="Blues")

# Customize the appearance of the chart
fig.update_traces(marker_line_color='rgb(8, 48, 107)',
                  marker_line_width=1.5, opacity=0.6)

fig.update_layout(plot_bgcolor='black', paper_bgcolor='black',
                  xaxis_title="Views", yaxis_title="Channel Name")

# Show the chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# we can see here that T-Series is still leading, MrBeast is not even in the top 10 highest viewed channels, Cocomelon took the 2nd position here with over 160b views and SETIndia third with over 150b views. We can see things happening here, almost the top10 highest viewed channels are entertainment channels I mean movies and shows. This is saying most youths in the world that use youtube are mostly hooked to entertainments. Also, parents now use Cocomelon as instrument for their babies.

# %% [markdown]
# Lets check for number of videos posted:

# %%
import plotly.express as px

# Sort the DataFrame by Video_Count in descending order
top_yt50_sorted = top_yt50.sort_values(by="Video_Count", ascending=False)

# Create the bar chart with a blue gradient color scale
fig = px.bar(top_yt50_sorted.head(10), x="Video_Count", y="channel_name",
             title="Top 10 YouTube Channels with the Most Videos",
             labels={"Video_Count": "Number of Videos", "channel_name": "Channel Name"},
             color="Video_Count", color_continuous_scale="Blues")

# Customize the appearance of the chart
fig.update_traces(marker_line_color='rgb(8, 48, 107)',
                  marker_line_width=1.5, opacity=0.6)

fig.update_layout(plot_bgcolor='black', paper_bgcolor='black',
                  xaxis_title="Number of Videos", yaxis_title="Channel Name")

# Show the chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Aaj Tak has posted the world's highest number of videos on youtube with over 300000 videos, we can see now that its not in the numbers of videos posted becauce TSeries has 19600 videos and over 235b views, that means on the average the have 12000 veiws per video posted, while Aaj Taj has 26794240999 views thats 893 veiws per video posted

# %%
# Create the scatter plot
fig = px.scatter(top_yt50, x="Subscribers", y="Views", size="Video_Count", color="Video_Count",
                 hover_name="channel_name", labels={"Video_Count": "Video Count"})

# Customize the appearance of the plot
fig.update_layout(title="Subscribers vs. Views for Top 50 YouTube Channels",
                  xaxis_title="Subscribers",
                  yaxis_title="Views",
                  coloraxis_colorbar_title="Video Count",
                  showlegend=False)  # Hide the legend for a cleaner look
# Set the background color to black for the entire chart
fig.update_layout(plot_bgcolor='black')
# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Create the scatter plot using Seaborn
plt.figure(figsize=(12, 6))  # Adjust the figure size
sns.set(style="darkgrid")  # Set the style to darkgrid for a dark background

# Create the scatter plot
sns.scatterplot(data=top_yt50, x="Subscribers", y="Views", size="Video_Count", hue="Video_Count")

# Customize the appearance of the plot
plt.title("Subscribers vs. Views for Top 50 YouTube Channels")
plt.xlabel("Subscribers")
plt.ylabel("Views")
plt.legend(title="Video Count", loc="upper right", bbox_to_anchor=(1.3, 1))

# Show the plot
plt.show()

# %%
# Create the scatter plot using Seaborn
plt.figure(figsize=(10, 6))  # Adjust the figure size
sns.set(style="darkgrid")  # Set the style to darkgrid for a dark background

# Create the scatter plot with a black background and sharp colors
plot = sns.scatterplot(data=top_yt50, x="Subscribers", y="Views", size="Video_Count", hue="Video_Count", palette="plasma")

# Customize the appearance of the plot
plt.title("Subscribers vs. Views for Top 50 YouTube Channels", color='white')
plt.xlabel("Subscribers", color='white')
plt.ylabel("Views", color='white')
plt.legend(title="Video Count", loc="upper right", bbox_to_anchor=(1.3, 1), title_fontsize='12', labels=['Low', 'Medium', 'High'])

# Set background color to black
plot.set_facecolor('black')

# Show the plot
plt.show()

# %% [markdown]
# Published Year Distribution:

# %%
# Extract the year from the "published" column
top_yt50['Published_Year'] = pd.to_datetime(top_yt50['published']).dt.year

# Create a histogram of the published years
plt.figure(figsize=(10, 6))
sns.set(style="darkgrid")
sns.histplot(data=top_yt50, x="Published_Year", bins=10, kde=True, color='skyblue')
plt.title("Published Year Distribution", color='white')
plt.xlabel("Year", color='white')
plt.ylabel("Count", color='white')
plt.show()

# %% [markdown]
# Subscribers Distribution:

# %%
plt.figure(figsize=(10, 6))
sns.set(style="darkgrid")
sns.histplot(data=top_yt50, x="Subscribers", bins=20, kde=True, color='salmon')
plt.title("Subscribers Distribution", color='white')
plt.xlabel("Subscribers", color='white')
plt.ylabel("Count", color='white')
plt.show()

# %% [markdown]
# Top 10 Channels with the Most Subscribers:

# %%
# Sort the DataFrame by subscribers in descending order and select the top 10
top_10_subscribers = top_yt50.sort_values(by="Subscribers", ascending=False).head(10)

# Display the top 10 channels with the most subscribers
top_10_subscribers[['channel_name', 'Subscribers']]
# Out:
#                   channel_name  Subscribers
# 21                    T-Series    251000000
# 4                      MrBeast    201000000
# 42  Cocomelon - Nursery Rhymes    166000000
# 29                   SET India    164000000
# 26           ✿ Kids Diana Show    114000000
# 37                   PewDiePie    111000000
# 48                 Like Nastya    108000000
# 33               Vlad and Niki    102000000
# 39           Zee Music Company    101000000
# 46                         WWE     97600000

# %% [markdown]
# Top 10 Channels with the Most Videos:

# %%
top_10_videos = top_yt50.nlargest(10, "Video_Count")
top_10_videos[['channel_name', 'Video_Count']]
# Out:
#              channel_name  Video_Count
# 13                Aaj Tak       307671
# 16              Colors TV       119824
# 29              SET India       119657
# 12               Sony SAB        74548
# 46                    WWE        71869
# 0              Movieclips        39612
# 28  T-Series Bhakti Sagar        26553
# 21               T-Series        19651
# 30                Badabun        19250
# 5                Shemaroo        11829

# %% [markdown]
# Views Distribution:

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=top_yt50, x="Views", bins=20, kde=True, color='lightgreen')
plt.title("Views Distribution", color='white')
plt.xlabel("Views", color='white')
plt.ylabel("Count", color='white')
plt.show()
